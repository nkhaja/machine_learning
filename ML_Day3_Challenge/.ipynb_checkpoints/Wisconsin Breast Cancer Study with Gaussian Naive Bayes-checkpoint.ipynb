# %% [markdown]
# Create another jupyter notebook from scratch.  Use a naive bayesian classifier (gaussianNB) to to classify samples from the Wisconsin Breast Cancer Study data set.  You can load this dataset directly from sklearn.datasets, or you can download it from the UCI machine learning data set repository.  Clean, prepare, visualize, and classify the dataset just like we did with the titanic and iris data sets.  You will be presenting your findings in Tuesday’s class!

# %%
#import libraries
import pandas as pd
import numpy as np
from sklearn import datasets

iris = datasets.load_iris()
all_data = datasets.load_breast_cancer()

numbers = all_data['data']
target = all_data['target']
target_names = all_data['target_names']
feature_names = all_data['feature_names']

df = pd.DataFrame(data=numbers, columns=feature_names)
df['target'] = target

#Check how to drop the first label
# Out:
# ['malignant' 'benign']

# %%
# Fill in missing values here

for column in df.columns:
    df[column].fillna(df[column].median())

# %%
df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0         17.990         10.38          122.80     1001.0          0.11840
# 1         20.570         17.77          132.90     1326.0          0.08474
# 2         19.690         21.25          130.00     1203.0          0.10960
# 3         11.420         20.38           77.58      386.1          0.14250
# 4         20.290         14.34          135.10     1297.0          0.10030
# 5         12.450         15.70           82.57      477.1          0.12780
# 6         18.250         19.98          119.60     1040.0          0.09463
# 7         13.710         20.83           90.20      577.9          0.11890
# 8         13.000         21.82           87.50      519.8          0.12730
# 9         12.460         24.04           83.97      475.9          0.11860
# 10        16.020         23.24          102.70      797.8          0.08206
# ...

# %%
import matplotlib.pyplot as plt
# Visualizing the data

for column in df.columns:
    plt.hist(df[column][df["target"] == 1], bins = 5)
    plt.hist(df[column][df["target"] == 0], bins = 5)
    plt.title(column)
    plt.show()

    
# for i in range len(df.columns)-1:
#     plt.figure(i)
#     plt.hist(df[df.columns[column]][df["Cancer"] == 0], bins = 5)

# plt.hist(df["mean texture"][df["target"] == 1], bins = 5)

# %% [markdown]
# Main features that differ between patients:
#
# * mean radius is much smaller
# * mean texture has more categories in the smaller ranger 15-20
# * mean area much smaller in cancer peeps
# * mean compactness compactness averages smaller
# * Massive difference in spread of concavity
# * Mean concave conave points averages much smaller
# * worst persmitter much smaller
# * worst concavity

# %%
# do the train test split

from sklearn.model_selection import train_test_split

train, test = train_test_split(df, train_size = 0.7)

# %%
# Build the model

from sklearn.naive_bayes import GaussianNB

target_features_train = train[["mean texture", "mean compactness", "worst perimeter"]].values
cancer_target_train = train["target"].values

gnb = GaussianNB().fit(target_features_train, cancer_target_train)
print(gnb.score(target_features_train, cancer_target_train))
# Out:
# 0.939698492462

# %%
from sklearn.metrics import f1_score


# check te prediction against the test set 
target_features_test = test[["mean texture", "mean compactness", "worst perimeter"]].values
cancer_target_test = test["target"].values

# Decision tree prediction
predict = gnb.predict(target_features_test)
score = f1_score(cancer_target_test, predict)
print(score)
# Out:
# 0.938388625592
